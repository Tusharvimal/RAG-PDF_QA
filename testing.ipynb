# %%
from pypdf import PdfReader
import pandas as pd
import os
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss
from dotenv import load_dotenv
from groq import Groq

# %%
load_dotenv()
# Out:
# True

# %%
reader = PdfReader('rag_test_document.pdf')

# %%
print(len(reader.pages))
# Out:
# 3

# %%
extracted_text = ""

for i in range(len(reader.pages)):
    extracted_text+=reader.pages[i].extract_text() + '\n'

# %%
extracted_text
# Out:
# "The History & Science of Coffee\n A Comprehensive Guide for Curious Minds\nOrigins and Early History\nCoffee's story begins in the highlands of Ethiopia, where legend tells of a goat herder named Kaldi who\nnoticed his goats becoming unusually energetic after eating berries from a certain tree. Although this tale\nmay be more myth than fact, what is historically confirmed is that coffee plants (Coffea species) originated\nin the Kaffa region of Ethiopia. By the 9th century, coffee was being cultivated and traded across the\nArabian Peninsula, particularly in Yemen, where Sufi monks used it to stay alert during long hours of\nprayer.\nThe first coffeehouses — known as qahveh khaneh — appeared in Persia and later spread throughout\nthe Ottoman Empire during the 15th and 16th centuries. These establishments quickly became important\nsocial hubs where people gathered to share news, engage in conversation, and enjoy music. By the 17th\ncentury, coffee had made its way to Europe, initially met with suspicion but soon embraced after Pope\nClement VIII gave it his approval.\n■ Quick Fact: The Dutch were the first Europeans to successfully cultivate coffee outside of Arabia,\nestablishing plantations in their colonies in Java (Indonesia) in the early 1600s.\nThe Global Spread\nCoffee's journey across the globe accelerated during the colonial era. The French brought coffee to\nMartinique in the Caribbean around 1715, and from there it spread rapidly through the Americas. Brazil,\nwhich began cultivating coffee in the 18th century, eventually became — and remains — the world's\nlargest coffee producer, responsible for roughly one-third of all global output.\nIndia also became a significant player in the coffee trade. According to legend, a Muslim saint named\nBaba Budan smuggled seven coffee beans into India in the 17th century, planting them in the hills of\nKarnataka. Today, Indian coffee — especially from regions like Nilgiris and Chikmagalur — is prized\ninternationally for its unique flavor profiles.\n\n— Page 2 of 3 —\nThe Science Behind the Brew\nCoffee is far more than a simple beverage — it is a complex chemical ecosystem. A single cup of coffee\ncontains over 800 distinct chemical compounds, many of which form during the roasting process. The\nmost well-known of these is caffeine (1,3,7-trimethylxanthine), a natural stimulant that blocks adenosine\nreceptors in the brain, thereby reducing feelings of tiredness and increasing alertness.\nBeyond caffeine, coffee is rich in chlorogenic acids, a family of antioxidants that have been linked to\nanti-inflammatory effects. Roasting breaks down chlorogenic acids while simultaneously creating new\ncompounds like melanoidins, which give dark roasts their characteristic color and contribute to the overall\nantioxidant profile of the drink.\n■ Quick Fact: Dark roasts actually contain slightly less caffeine than light roasts. This is because longer\nroasting times cause more caffeine molecules to sublimate (convert from solid to gas).\nRoasting: Where Flavor Is Born\nGreen (unroasted) coffee beans are pale, hard, and have very little aroma or flavor. It is the roasting\nprocess — typically carried out at temperatures between 180°C and 240°C (356°F–464°F) — that\ntransforms them into the aromatic beans we know. Roasting triggers a series of chemical reactions, most\nnotably the Maillard reaction, which creates hundreds of flavor and aroma compounds.\nCoffee roasts are generally categorized into three main levels:\n■ Light Roasts — Roasted at lower temperatures (around 180–205°C). The beans retain more of their\noriginal flavor characteristics, often showcasing fruity, floral, or acidic notes. The surface remains dry with\nno visible oil.\n■ Medium Roasts — Roasted at moderate temperatures (around 205–220°C). These offer a balanced\nflavor with a mix of original bean character and roast-developed sweetness. They are the most popular\nchoice worldwide.\n■ Dark Roasts — Roasted at higher tempe ...

# %%
len(extracted_text)
# Out:
# 6403

# %%
cleaned_text = extracted_text.replace('\n',' ')
print(cleaned_text)
# Out:
# The History & Science of Coffee  A Comprehensive Guide for Curious Minds Origins and Early History Coffee's story begins in the highlands of Ethiopia, where legend tells of a goat herder named Kaldi who noticed his goats becoming unusually energetic after eating berries from a certain tree. Although this tale may be more myth than fact, what is historically confirmed is that coffee plants (Coffea species) originated in the Kaffa region of Ethiopia. By the 9th century, coffee was being cultivated and traded across the Arabian Peninsula, particularly in Yemen, where Sufi monks used it to stay alert during long hours of prayer. The first coffeehouses — known as qahveh khaneh — appeared in Persia and later spread throughout the Ottoman Empire during the 15th and 16th centuries. These establishments quickly became important social hubs where people gathered to share news, engage in conversation, and enjoy music. By the 17th century, coffee had made its way to Europe, initially met with suspicion but soon embraced after Pope Clement VIII gave it his approval. ■ Quick Fact: The Dutch were the first Europeans to successfully cultivate coffee outside of Arabia, establishing plantations in their colonies in Java (Indonesia) in the early 1600s. The Global Spread Coffee's journey across the globe accelerated during the colonial era. The French brought coffee to Martinique in the Caribbean around 1715, and from there it spread rapidly through the Americas. Brazil, which began cultivating coffee in the 18th century, eventually became — and remains — the world's largest coffee producer, responsible for roughly one-third of all global output. India also became a significant player in the coffee trade. According to legend, a Muslim saint named Baba Budan smuggled seven coffee beans into India in the 17th century, planting them in the hills of Karnataka. Today, Indian coffee — especially from regions like Nilgiris and Chikmagalur — is prized internationally for its unique flavor profiles.  — Page 2 of 3 — The Science Behind the Brew Coffee is far more than a simple beverage — it is a complex chemical ecosystem. A single cup of coffee contains over 800 distinct chemical compounds, many of which form during the roasting process. The most well-known of these is caffeine (1,3,7-trimethylxanthine), a natural stimulant that blocks adenosine receptors in the brain, thereby reducing feelings of tiredness and increasing alertness. Beyond caffeine, coffee is rich in chlorogenic acids, a family of antioxidants that have been linked to anti-inflammatory effects. Roasting breaks down chlorogenic acids while simultaneously creating new compounds like melanoidins, which give dark roasts their characteristic color and contribute to the overall antioxidant profile of the drink. ■ Quick Fact: Dark roasts actually contain slightly less caffeine than light roasts. This is because longer roasting times cause more caffeine molecules to sublimate (convert from solid to gas). Roasting: Where Flavor Is Born Green (unroasted) coffee beans are pale, hard, and have very little aroma or flavor. It is the roasting process — typically carried out at temperatures between 180°C and 240°C (356°F–464°F) — that transforms them into the aromatic beans we know. Roasting triggers a series of chemical reactions, most notably the Maillard reaction, which creates hundreds of flavor and aroma compounds. Coffee roasts are generally categorized into three main levels: ■ Light Roasts — Roasted at lower temperatures (around 180–205°C). The beans retain more of their original flavor characteristics, often showcasing fruity, floral, or acidic notes. The surface remains dry with no visible oil. ■ Medium Roasts — Roasted at moderate temperatures (around 205–220°C). These offer a balanced flavor with a mix of original bean character and roast-developed sweetness. They are the most popular choice worldwide. ■ Dark Roasts — Roasted at higher temperatures (above 220°C). The beans develop bold, smok ...

# %%
def chunk_text(text, chunk_size = 300, overlap = 50):
    chunks = []
    start = 0
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start: end])
        start += chunk_size - overlap
    return chunks

chunks = chunk_text(cleaned_text)
len(chunks)
# Out:
# 26

# %%
chunks
# Out:
# ["The History & Science of Coffee  A Comprehensive Guide for Curious Minds Origins and Early History Coffee's story begins in the highlands of Ethiopia, where legend tells of a goat herder named Kaldi who noticed his goats becoming unusually energetic after eating berries from a certain tree. Although",
#  'after eating berries from a certain tree. Although this tale may be more myth than fact, what is historically confirmed is that coffee plants (Coffea species) originated in the Kaffa region of Ethiopia. By the 9th century, coffee was being cultivated and traded across the Arabian Peninsula, particul',
#  ' and traded across the Arabian Peninsula, particularly in Yemen, where Sufi monks used it to stay alert during long hours of prayer. The first coffeehouses — known as qahveh khaneh — appeared in Persia and later spread throughout the Ottoman Empire during the 15th and 16th centuries. These establish',
#  'uring the 15th and 16th centuries. These establishments quickly became important social hubs where people gathered to share news, engage in conversation, and enjoy music. By the 17th century, coffee had made its way to Europe, initially met with suspicion but soon embraced after Pope Clement VIII ga',
#  "icion but soon embraced after Pope Clement VIII gave it his approval. ■ Quick Fact: The Dutch were the first Europeans to successfully cultivate coffee outside of Arabia, establishing plantations in their colonies in Java (Indonesia) in the early 1600s. The Global Spread Coffee's journey across the ",
#  "0s. The Global Spread Coffee's journey across the globe accelerated during the colonial era. The French brought coffee to Martinique in the Caribbean around 1715, and from there it spread rapidly through the Americas. Brazil, which began cultivating coffee in the 18th century, eventually became — an",
#  "coffee in the 18th century, eventually became — and remains — the world's largest coffee producer, responsible for roughly one-third of all global output. India also became a significant player in the coffee trade. According to legend, a Muslim saint named Baba Budan smuggled seven coffee beans into",
#  ' named Baba Budan smuggled seven coffee beans into India in the 17th century, planting them in the hills of Karnataka. Today, Indian coffee — especially from regions like Nilgiris and Chikmagalur — is prized internationally for its unique flavor profiles.  — Page 2 of 3 — The Science Behind the Brew',
#  'iles.  — Page 2 of 3 — The Science Behind the Brew Coffee is far more than a simple beverage — it is a complex chemical ecosystem. A single cup of coffee contains over 800 distinct chemical compounds, many of which form during the roasting process. The most well-known of these is caffeine (1,3,7-tri',
#  'he most well-known of these is caffeine (1,3,7-trimethylxanthine), a natural stimulant that blocks adenosine receptors in the brain, thereby reducing feelings of tiredness and increasing alertness. Beyond caffeine, coffee is rich in chlorogenic acids, a family of antioxidants that have been linked t',
#  ', a family of antioxidants that have been linked to anti-inflammatory effects. Roasting breaks down chlorogenic acids while simultaneously creating new compounds like melanoidins, which give dark roasts their characteristic color and contribute to the overall antioxidant profile of the drink. ■ Quic',
#  'e overall antioxidant profile of the drink. ■ Quick Fact: Dark roasts actually contain slightly less caffeine than light roasts. This is because longer roasting times cause more caffeine molecules to sublimate (convert from solid to gas). Roasting: Where Flavor Is Born Green (unroasted) coffee beans',
#  'here Flavor Is Born Green (unroasted) coffee beans are pale, hard, and have very little aroma or flavor. It is the roasting process — typically carried out at temperatures between 180°C and 240°C (356°F–464°F) — that transforms them into the aromatic beans we know. Roasting triggers a series of chem',
#  ' beans we know. Roasting triggers a series of chemical reactions, most notably the Maillard reaction, which creates hundreds of flavor and aroma compounds. Coffee roasts are generally categorized into three main levels: ■ Light Roasts — Roasted at lower temperatures (around 180–205°C). The beans ret',
#  'wer temperatures (around 180–205°C). The beans retain more of their original flavor characteristics, often showcasing fruity, floral, or acidic notes. The surface remains dry with no visible oil. ■ Medium Roasts — Roasted at moderate temperatures (around 205–220°C). These offer a balanced flavor wit',
#  'ound 205–220°C). These offer a balanced flavor with a mix of original bean character and roast-developed sweetness. They are the most popular choice worldwide. ■ Dark Roasts — Roasted at higher temperatures (above 220°C). The beans develop bold, smoky, bitter, and chocolatey flavors. Oils begin to a',
#  'y, bitter, and chocolatey flavors. Oils begin to appear on the surface, and the original bean character is largely masked by roast flavors.  — Page 3 of 3 — Health Effects of Coffee For years, coffee had a reputation as an unhealthy habit. Modern research has painted a dramatically different picture',
#  "earch has painted a dramatically different picture. Multiple large-scale studies have found that moderate coffee consumption (generally 3–5 cups per day) is associated with several health benefits, including a reduced risk of Type 2 diabetes, Parkinson's disease, Alzheimer's disease, and certain liv",
#  "on's disease, Alzheimer's disease, and certain liver conditions such as cirrhosis. Coffee also contains significant amounts of magnesium, potassium, and vitamin B2 (riboflavin). In fact, for many people in Western countries, coffee is the single largest dietary source of antioxidants. However, exces",
#  'est dietary source of antioxidants. However, excessive consumption (more than 5–6 cups daily) can lead to insomnia, anxiety, increased heart rate, and digestive discomfort. ■ Quick Fact: Caffeine has a half-life of approximately 5–6 hours in most adults, meaning that if you drink a cup of coffee at ',
#  'lts, meaning that if you drink a cup of coffee at 2:00 PM, roughly half the caffeine is still in your system at 7:00–8:00 PM. Brewing Methods and Their Impact The way coffee is brewed significantly affects its taste, strength, and chemical composition. Here are some of the most popular methods: ■ Es',
#  'n. Here are some of the most popular methods: ■ Espresso — Uses high-pressure (around 9 bars) hot water forced through finely ground coffee. Produces a concentrated shot with a rich, creamy crema on top. Espresso is the base for lattes, cappuccinos, and americanos. ■ Pour Over — A manual brewing met',
#  'and americanos. ■ Pour Over — A manual brewing method where hot water is slowly poured over ground coffee in a filter. It offers precise control over brewing time and temperature, resulting in a clean, nuanced flavor. ■ French Press — Coffee grounds steep directly in hot water for about 4 minutes be',
#  'steep directly in hot water for about 4 minutes before being separated by a metal plunger. This method extracts more oils and solids, giving the cup a fuller, heavier body. ■ Cold Brew — Coffee grounds are steeped in cold water for 12–24 hours. The result is a smooth, low-acidity drink that is natur',
#  'esult is a smooth, low-acidity drink that is naturally sweeter than hot-brewed coffee. Summary: From its legendary Ethiopian origins to the complex chemistry behind every cup, coffee is one of the most fascinating beverages in human history. Whether you enjoy a light, fruity pour-over or a bold espr',
#  'you enjoy a light, fruity pour-over or a bold espresso shot, understanding what goes into your cup can deepen your appreciation of this timeless drink.  ']

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

embeddings = embedding_model.encode(chunks)
embeddings.shape
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1133.43it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (26, 384)

# %%
embeddings = np.array(embeddings, dtype = np.float32)

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(embeddings)

print(f"Total Vectors stored: {index.ntotal}")
# Out:
# Total Vectors stored: 26

# %%
query = "Where did coffee plants originally come from?"

query_emb = embedding_model.encode([query])

distances, indices = index.search(query_emb, k = 3)

for i, idx in enumerate(indices[0]):
    print(f"Result{i+1}")
    print(chunks[idx])
# Out:
# Result1
# after eating berries from a certain tree. Although this tale may be more myth than fact, what is historically confirmed is that coffee plants (Coffea species) originated in the Kaffa region of Ethiopia. By the 9th century, coffee was being cultivated and traded across the Arabian Peninsula, particul
# Result2
# icion but soon embraced after Pope Clement VIII gave it his approval. ■ Quick Fact: The Dutch were the first Europeans to successfully cultivate coffee outside of Arabia, establishing plantations in their colonies in Java (Indonesia) in the early 1600s. The Global Spread Coffee's journey across the
# Result3
#  named Baba Budan smuggled seven coffee beans into India in the 17th century, planting them in the hills of Karnataka. Today, Indian coffee — especially from regions like Nilgiris and Chikmagalur — is prized internationally for its unique flavor profiles.  — Page 2 of 3 — The Science Behind the Brew

# %%
print(indices)
# Out:
# [[1 4 7]]

# %%
context = ""

for idx in indices[0]:
    context += chunks[idx] + " "

# %%
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

# %%
prompt = f"""Answer the following question based only on the provided context. If the answer is not in the context, say "I don't have enough information to answer that."

Context: {context}

Question: {query}

Answer:"""

# %%
response = client.chat.completions.create(
    model = 'llama-3.1-8b-instant',
    messages=[
        {'role': "system","content": "You are helpful assistant that answers questions based on the provided context."},
        {'role': 'user', 'content': prompt}
    ],
    temperature=0.3,
    max_tokens=500
)

answer = response.choices[0].message.content
print(f'\n Answer: {answer}')
# Out:
#  Answer: Coffee plants (Coffea species) originally came from the Kaffa region of Ethiopia.
